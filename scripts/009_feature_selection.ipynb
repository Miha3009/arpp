# %%
from models import LinearRegression, BoostingModel, create_nn, MLPModel
from train import ClimateDataset, evaluate, make_train_test
import pandas as pd
import torch
import numpy as np
import itertools
from tqdm.notebook import tqdm

def feature_importance(booster):
    return pd.DataFrame({
        'feature': booster.feature_name(),
        'importance': booster.feature_importance(importance_type='gain')
    }).sort_values('importance', ascending=False).reset_index(drop=True)

FIRST_YEAR = 2007
SPLIT_YEAR = 2016
LAST_YEAR = 2019

def make_ds(element, args):
    return make_train_test(element, FIRST_YEAR, SPLIT_YEAR, LAST_YEAR, args)

# %%
ds = ClimateDataset('aice', lead_times=[3], periods=[3])
model = BoostingModel(variables=ds.variables.copy())
model.fit(ds)
feature_importance(model.model)
# Out:
#        feature     importance
# 0         aice  243846.577600
# 1      cos_lat   16729.302294
# 2           ps    8547.605698
# 3         t850    7712.167528
# 4      sin_lon    7097.492949
# 5          olr    6993.244529
# 6         h500    6824.411523
# 7         hice    6786.388554
# 8         v850    6028.637073
# 9          sst    5990.564500
# 10     cos_lon    3785.110461
# 11       t2max    3441.390424
# 12        u850    3130.765502
# 13        uv10    2735.834682
# 14         rq2    2599.944957
# 15       t2min    1910.994256
# 16          t2    1437.713337
# 17         cld    1179.115872
# 18        prec    1131.609003
# 19  sin_period       0.000000
# 20  cos_period       0.000000

# %%
ds = ClimateDataset('swe', lead_times=[3], periods=list(range(44, 49)))
model = BoostingModel(variables=ds.variables.copy())
model.fit(ds)
feature_importance(model.model)
# Out:
#        feature   importance
# 0        t2min  540728356.0
# 1          swe  345903520.0
# 2      cos_lat  290962796.0
# 3      cos_lon  237870206.0
# 4      sin_lon  221507471.0
# 5          tvl  218294927.0
# 6         sdor  189033583.0
# 7         h500  168372332.0
# 8           t2  158488576.0
# 9           ww  147749781.0
# 10        v850  132091792.0
# 11          ps  103620215.0
# 12        u850  102618582.0
# 13           z   87582560.0
# 14         olr   85790871.0
# 15        t850   78501741.0
# 16         cld   64410021.0
# 17        prec   58880406.0
# 18          ws   57867869.0
# 19       t2max   55318679.0
# 20         cvl   51401595.0
# 21        uv10   50330413.0
# 22  sin_period   49463002.0
# 23         lsm   37055644.0
# 24         slt   36109084.0
# 25         rq2   23785139.0
# 26         cvh   20626886.0
# 27  cos_period   15826003.0
# 28          cl    7222562.0
# 29         tvh    2896815.0

# %%
def score_model(model, X, y, lat, climate, s, mx=1):
    model.__fit__(X[:, s], y)
    y_pred = torch.clamp(model.predict(X[:, s]) + climate, 0, max=mx)
    return loss_rmse(y_pred, y + climate, lat)

def shapley_approximation(model, variables, X, y, lat, climate, mx=1, n_samples=500):
    n = X.shape[1]
    shapley_values = np.zeros(n)
    
    for _ in tqdm(range(n_samples)):
        order = np.random.permutation(n)
        cur_set = []
        prev_score = score_model(model, X, y, lat, climate, cur_set, mx=mx)
        for i, idx in enumerate(order):
            cur_set.append(idx)
            cur_score = score_model(model, X, y, lat, climate, cur_set, mx=mx)
            for idx in cur_set:
                shapley_values[idx] += (cur_score - prev_score) / (i + 1)
            prev_score = cur_score
    shapley_values /= n_samples / 1000

    return pd.DataFrame({
        'variable': variables,
        'SHAP': -shapley_values
    }).sort_values('SHAP', ascending=False).reset_index(drop=True)

# %%
ds = ClimateDataset('aice', lead_times=[3], periods=[3], normed=True, use_cache=True)
ds.set_variables([v for v in ds.variables if v not in ['cos_period', 'sin_period']])
X, y, lat, climate = ds.load_all()
shapley_approximation(LinearRegression([]), ds.variables.copy(), X, y, lat, climate, n_samples=1000)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#    variable      SHAP
# 0      aice  5.786736
# 1   cos_lat  3.000968
# 2        ps  1.675598
# 3       sst  1.665752
# 4     t2min  1.640753
# 5       olr  1.636141
# 6      t850  1.621056
# 7      uv10  1.587313
# 8     t2max  1.576886
# 9      prec  1.547284
# 10       t2  1.531745
# 11     v850  1.529202
# 12     hice  1.523626
# 13     u850  1.522739
# 14     h500  1.521812
# 15      rq2  1.510334
# 16  sin_lon  1.505852
# 17  cos_lon  1.500664
# 18      cld  1.462086

# %%
full_variables = ['hice', 'sst', 'aice', 'cld', 'h500', 'olr', 'prec', 'ps', 'rq2', 't2', 't2max', 't2min', 't850',
                  'u850', 'uv10', 'v850', 'cos_lat', 'sin_lon', 'cos_lon', 'sin_period', 'cos_period']
dsTrain, dsTest = make_ds('aice', args={"lead_times": [3], "periods": [3], "normed": True, "cache_level": 2, "batch_size": 1e8,
                                        "variables": full_variables})
model = create_nn('aice', MLPModel,
            {'input_size': len(dsTrain.variables), 'hidden_layers': [16, 8] },
            test=dsTest, lr=0.003, epochs=170, verbose=False)
#trainLoss, testLoss = model.fit(dsTrain)
testLoss[-1]
# Out:
# ([-0.45431843400001526,
#   -0.4350205361843109,
#   -0.41617515683174133,
#   -0.3975442051887512,
#   -0.37892934679985046,
#   -0.36052724719047546,
#   -0.3425058126449585,
#   -0.3250606656074524,
#   -0.3081733286380768,
#   -0.2916460335254669,
#   -0.27522698044776917,
#   -0.2587161958217621,
#   -0.24195346236228943,
#   -0.2249734103679657,
#   -0.20791257917881012,
#   -0.1907934546470642,
#   -0.1736024022102356,
#   -0.15639682114124298,
#   -0.13920176029205322,
#   -0.12198332697153091,
#   -0.10464233160018921,
#   -0.0870252475142479,
#   -0.06889922171831131,
#   -0.04995371773838997,
#   -0.029764924198389053,
#   -0.007742252200841904,
#   0.01692875660955906,
#   0.04542296752333641,
#   0.07928164303302765,
#   0.12064426392316818,
#   0.17218369245529175,
#   0.23657715320587158,
#   0.31504103541374207,
#   0.4041192829608917,
#   0.49140337109565735,
#   0.5590240359306335,
#   0.5963003635406494,
#   0.6096937656402588,
#   0.6121944189071655,
# ...

# %%
def get_loss(variant, X, y, lat, X_test, y_test, lat_test, variables, idxs):
    model = None
    if variant == 'aice':
        model = create_nn('aice', MLPModel,
            {'input_size': len(variables), 'hidden_layers': [4, 2] }, lr=0.04, epochs=200, verbose=False)
    elif variant == 'swe':
        model = create_nn('swe', MLPModel,
            {'input_size': len(variables), 'hidden_layers': [4, 4] }, lr=0.01, epochs=60, verbose=False)

    trainLosses, testLosses = model.fit_simple(X[:, idxs], y, lat, X_test[:, idxs], y_test, lat_test)
    return np.max(testLosses)

def feature_selection(variant, variables):
    history = []
    current_vars = variables.copy()
    current_idxs = list(range(len(variables)))

    dsTrain, dsTest = make_ds('aice', args={
        "lead_times": [3], "periods": [3], "normed": True, "batch_size": 1e8, "variables": variables, 'cache_level': 0
    }) if variant == 'aice' else make_ds('swe', args={
        "lead_times": [3], "periods": [44, 45, 46, 47], "normed": True, "batch_size": 1e8, "variables": variables, 'cache_level': 0
    })
    X, y, lat = dsTrain.load_all()
    X_test, y_test, lat_test = dsTest.load_all()

    current_loss = get_loss(variant, X, y, lat, X_test, y_test, lat_test, current_vars, current_idxs)
    print(np.round(current_loss, 3), current_vars)
    history.append({'variables': ';'.join(current_vars), 'loss': current_loss})

    while len(current_vars) > 1:
        best_vars = None
        best_idxs = None
        best_loss = 0
        
        for i_remove, v_remove in zip(current_idxs, current_vars):
            candidate_vars = [v for v in current_vars if v != v_remove]
            candidate_idxs = [i for i in current_idxs if i != i_remove]
            candidate_loss = get_loss(variant, X, y, lat, X_test, y_test, lat_test, candidate_vars, candidate_idxs)

            if candidate_loss > best_loss:
                best_loss = candidate_loss
                best_vars = candidate_vars
                best_idxs = candidate_idxs

        current_vars = best_vars
        current_idxs = best_idxs
        current_loss = best_loss
        print(np.round(current_loss, 3), current_vars)
        history.append({'variables': ';'.join(current_vars), 'loss': current_loss})
        pd.DataFrame(history).to_csv(f'009_{variant}.csv', index=False)
 
    df = pd.DataFrame(history)
    df.to_csv(f'009_{variant}.csv', index=False)
    return df

# %%
ice_variables = ['hice', 'sst', 'aice', 'cld', 'h500', 'olr', 'prec', 'ps', 'rq2', 't2', 't2max', 't2min', 't850',
                  'u850', 'uv10', 'v850', 'cos_lat', 'sin_lon', 'cos_lon', 'sin_period', 'cos_period']
feature_selection('aice', ice_variables)
# Out:
# 0.846 ['hice', 'sst', 'aice', 'cld', 'h500', 'olr', 'prec', 'ps', 'rq2', 't2', 't2max', 't2min', 't850', 'u850', 'uv10', 'v850', 'cos_lat', 'sin_lon', 'cos_lon', 'sin_period', 'cos_period']
# 0.847 ['hice', 'sst', 'aice', 'cld', 'h500', 'olr', 'prec', 'ps', 'rq2', 't2', 't2max', 't2min', 't850', 'u850', 'uv10', 'cos_lat', 'sin_lon', 'cos_lon', 'sin_period', 'cos_period']
# 0.857 ['hice', 'sst', 'aice', 'cld', 'h500', 'prec', 'ps', 'rq2', 't2', 't2max', 't2min', 't850', 'u850', 'uv10', 'cos_lat', 'sin_lon', 'cos_lon', 'sin_period', 'cos_period']
# 0.856 ['hice', 'sst', 'aice', 'cld', 'h500', 'prec', 'ps', 'rq2', 't2', 't2max', 't2min', 't850', 'u850', 'cos_lat', 'sin_lon', 'cos_lon', 'sin_period', 'cos_period']
# 0.858 ['hice', 'sst', 'aice', 'cld', 'h500', 'prec', 'rq2', 't2', 't2max', 't2min', 't850', 'u850', 'cos_lat', 'sin_lon', 'cos_lon', 'sin_period', 'cos_period']
# ...

# %%
swe_variables = ['swe', 'cld', 'h500', 'olr', 'prec', 'ps', 'rq2', 't2', 't2max', 't2min', 't850', 'u850', 'uv10', 'v850', 'ws', 'ww',
            'z', 'sdor', 'cos_lat', 'sin_lon', 'cos_lon']
feature_selection('swe', swe_variables)
# Out:
# 0.242 ['swe', 'cld', 'h500', 'olr', 'prec', 'ps', 'rq2', 't2', 't2max', 't2min', 't850', 'u850', 'uv10', 'v850', 'ws', 'ww', 'z', 'sdor', 'cos_lat', 'sin_lon', 'cos_lon']
# 0.286 ['swe', 'cld', 'h500', 'olr', 'prec', 'ps', 'rq2', 't2', 't2max', 't2min', 't850', 'u850', 'uv10', 'v850', 'ww', 'z', 'sdor', 'cos_lat', 'sin_lon', 'cos_lon']
# 0.29 ['swe', 'cld', 'olr', 'prec', 'ps', 'rq2', 't2', 't2max', 't2min', 't850', 'u850', 'uv10', 'v850', 'ww', 'z', 'sdor', 'cos_lat', 'sin_lon', 'cos_lon']
# 0.291 ['swe', 'cld', 'olr', 'prec', 'ps', 'rq2', 't2', 't2max', 't2min', 't850', 'u850', 'uv10', 'ww', 'z', 'sdor', 'cos_lat', 'sin_lon', 'cos_lon']
# 0.234 ['swe', 'olr', 'prec', 'ps', 'rq2', 't2', 't2max', 't2min', 't850', 'u850', 'uv10', 'ww', 'z', 'sdor', 'cos_lat', 'sin_lon', 'cos_lon']
# 0.228 ['swe', 'olr', 'prec', 'ps', 'rq2', 't2', 't2max', 't2min', 't850', 'u850', 'uv10', 'ww', 'sdor', 'cos_lat', 'sin_lon', 'cos_lon']
# ...

# %%
variables = ['swe', 'cld', 'olr', 'prec', 'ps', 'rq2', 't2', 't2max', 't2min', 't850', 'u850', 'uv10', 'ww', 'z',
             'sdor', 'cos_lat', 'sin_lon', 'cos_lon']
dsTrain, dsTest = make_ds('swe', args={
        "lead_times": [3], "periods": [44, 45, 46, 47, 48], "normed": True, "batch_size": 1e8, "variables": variables, 'cache_level': 2
    })
model = create_nn('swe', MLPModel, {'input_size': len(variables), 'hidden_layers': [4, 4] }, lr=0.05, epochs=500, verbose=True, test=dsTest)
model.fit(dsTrain)
# Out:
# Epoch   1, train loss:   9.5115, test loss:   0.1720, time: 8.02s
# Epoch   2, train loss:   9.4800, test loss:   0.1743, time: 0.09s
# Epoch   3, train loss:   9.4478, test loss:   0.1746, time: 0.09s
# Epoch   4, train loss:   9.4085, test loss:   0.1742, time: 0.09s
# Epoch   5, train loss:   9.3600, test loss:   0.1737, time: 0.09s
# Epoch   6, train loss:   9.3027, test loss:   0.1728, time: 0.08s
# Epoch   7, train loss:   9.2388, test loss:   0.1716, time: 0.09s
# Epoch   8, train loss:   9.1765, test loss:   0.1712, time: 0.09s
# Epoch   9, train loss:   9.1343, test loss:   0.1725, time: 0.08s
# Epoch  10, train loss:   9.1293, test loss:   0.1754, time: 0.09s
# Epoch  11, train loss:   9.1340, test loss:   0.1787, time: 0.09s
# Epoch  12, train loss:   9.1170, test loss:   0.1825, time: 0.08s
# Epoch  13, train loss:   9.0816, test loss:   0.1866, time: 0.09s
# Epoch  14, train loss:   9.0414, test loss:   0.1909, time: 0.09s
# ...
